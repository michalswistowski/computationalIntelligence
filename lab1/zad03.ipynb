# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# importowanie modułów pandas i matplotlib

# %%
miasta = pd.read_csv('./miasta.csv')

row = {'Rok': 2010, 'Gdansk':460, 'Poznan':555, 'Szczecin':405}

miasta.loc[len(miasta.index)] = row
print(miasta)
# Out:
#      Rok  Gdansk  Poznan  Szczecin
# 0   1900     170     110       210
# 1   1925     210     220       254
# 2   1939     250     274       287
# 3   1946     117     267        72
# 4   1950     194     320       178
# 5   1960     286     408       269
# 6   1970     365     471       338
# 7   1980     456     552       388
# 8   1990     465     590       413
# 9   2000     462     574       416
# 10  2010     460     555       405

# %% [markdown]
# odczyt z pliku, dodanie wiersza

# %%
miasta = pd.DataFrame(miasta)

miasta.plot(x='Rok', ylabel='ludnosc[w tys]', marker='o')

plt.title(label='ludnosc w miastach polski')
plt.show()

# %% [markdown]
# stworzenie wykresu ludności trzech miast z danych

# %%
#e
miasta_standarized = miasta[['Gdansk', 'Poznan', 'Szczecin']].copy()
mean_before = miasta_standarized.values.mean()
std_before = miasta_standarized.values.std()
print("srednia poczatkowa: " + str(mean_before))
print("odchylenie standardowe poczatkowe: " + str(std_before))
miasta_standarized['Gdansk'] = (miasta_standarized['Gdansk'] - mean_before) / std_before
miasta_standarized['Poznan'] = (miasta_standarized['Poznan'] - mean_before) / std_before
miasta_standarized['Szczecin'] = (miasta_standarized['Szczecin'] - mean_before) / std_before
mean_after = miasta_standarized.values.mean()
std_after = miasta_standarized.values.std()
print(miasta_standarized)
print("srednia po standaryzacji: " + str(mean_after))
print("odchylenie standardowe po standaryzacji: " + str(miasta_standarized.values.std()))
# Out:
# srednia poczatkowa: 333.5151515151515
# odchylenie standardowe poczatkowe: 139.36112261927397
#       Gdansk    Poznan  Szczecin
# 0  -1.173320 -1.603856 -0.886296
# 1  -0.886296 -0.814540 -0.570569
# 2  -0.599272 -0.427057 -0.333774
# 3  -1.553627 -0.477286 -1.876529
# 4  -1.001105 -0.096979 -1.115915
# 5  -0.340950  0.534474 -0.462935
# 6   0.225923  0.986537  0.032181
# 7   0.878903  1.567760  0.390962
# 8   0.943483  1.840433  0.570352
# 9   0.921956  1.725624  0.591878
# 10  0.907605  1.589287  0.512947
# srednia po standaryzacji: 9.756505367918042e-17
# odchylenie standardowe po standaryzacji: 1.0

# %% [markdown]
# kopiujemy dane ktore bedziemy standaryzowac, standaryzujemy uzywajac wzoru z = (x - mean(x)) / std(x), obliczamy srednia i odchylenie standardowe po standaryzacji(srednia???)

# %%
miasta_normalized = miasta[['Gdansk', 'Poznan', 'Szczecin']].copy()
min_before = miasta_normalized.values.min()
max_before = miasta_normalized.values.max()
print("min poczatkowe: " + str(min_before) + " max poczatkowe: " + str(max_before))
miasta_normalized['Gdansk'] = (miasta_normalized['Gdansk'] - min_before) / (max_before - min_before)
miasta_normalized['Poznan'] = (miasta_normalized['Poznan'] - min_before) / (max_before - min_before)
miasta_normalized['Szczecin'] = (miasta_normalized['Szczecin'] - min_before) / (max_before - min_before)
print(miasta_normalized)
min_after = miasta_normalized.values.min()
max_after = miasta_normalized.values.max()
print("min po normalizacji: " + str(min_after))
print("max po normalizacji: " + str(max_after))
# Out:
# min poczatkowe: 72 max poczatkowe: 590
#       Gdansk    Poznan  Szczecin
# 0   0.189189  0.073359  0.266409
# 1   0.266409  0.285714  0.351351
# 2   0.343629  0.389961  0.415058
# 3   0.086873  0.376448  0.000000
# 4   0.235521  0.478764  0.204633
# 5   0.413127  0.648649  0.380309
# 6   0.565637  0.770270  0.513514
# 7   0.741313  0.926641  0.610039
# 8   0.758687  1.000000  0.658301
# 9   0.752896  0.969112  0.664093
# 10  0.749035  0.932432  0.642857
# min po normalizacji: 0.0
# max po normalizacji: 1.0

# %% [markdown]
# kopiujemy dane do normalizacji, normalizujemy dane za pomoca wzoru z = (x - min(x)) / (max(x) - min(x)), obliczamy wartosc min i max po normalizacji
